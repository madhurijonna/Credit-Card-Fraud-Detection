# %%
# !pip install import-ipynb
# !pip install termcolor
# !pip install xgboost
import import_ipynb
import main ### Importing main.ipynb
# Out:
# Requirement already satisfied: import-ipynb in c:\users\mouni\anaconda3\lib\site-packages (0.2)
# Requirement already satisfied: IPython in c:\users\mouni\anaconda3\lib\site-packages (from import-ipynb) (8.27.0)
# Requirement already satisfied: nbformat in c:\users\mouni\anaconda3\lib\site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: decorator in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: colorama in c:\users\mouni\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.4.6)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\mouni\anaconda3\lib\site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mouni\anaconda3\lib\site-packages (from nbformat->import-ipynb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\mouni\anaconda3\lib\site-packages (from nbformat->import-ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\mouni\anaconda3\lib\site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mouni\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mouni\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mouni\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mouni\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mouni\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\mouni\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (305.1)
# Requirement already satisfied: wcwidth in c:\users\mouni\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: executing in c:\users\mouni\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\mouni\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\mouni\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: six in c:\users\mouni\anaconda3\lib\site-packages (from asttokens->stack-data->IPython->import-ipynb) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\mouni\anaconda3\lib\site-packages (3.3.0)
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\mouni\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\mouni\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.2.0-py3-none-win_amd64.whl (101.7 MB)
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    - -------------------------------------- 2.6/101.7 MB 15.1 MB/s eta 0:00:07
#    --- ------------------------------------ 7.9/101.7 MB 19.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 11.3/101.7 MB 19.6 MB/s eta 0:00:05
#    ------ --------------------------------- 16.3/101.7 MB 20.1 MB/s eta 0:00:05
#    -------- ------------------------------- 21.0/101.7 MB 21.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 26.0/101.7 MB 21.1 MB/s eta 0:00:04
#    ------------ --------------------------- 31.2/101.7 MB 21.5 MB/s eta 0:00:04
#    -------------- ------------------------- 36.4/101.7 MB 21.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 40.9/101.7 MB 22.0 MB/s eta 0:00:03
#    ------------------ --------------------- 46.4/101.7 MB 22.2 MB/s eta 0:00:03
#    -------------------- ------------------- 51.6/101.7 MB 22.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 56.9/101.7 MB 22.6 MB/s eta 0:00:02
#    ------------------------ --------------- 62.1/101.7 MB 22.8 MB/s eta 0:00:02
#    -------------------------- ------------- 67.1/101.7 MB 22.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 71.3/101.7 MB 22.6 MB/s eta 0:00:02
#    ------------------------------ --------- 76.3/101.7 MB 22.7 MB/s eta 0:00:02
#    -------------------------------- ------- 81.5/101.7 MB 22.9 MB/s eta 0:00:01
#    --------------------------------- ------ 86.2/101.7 MB 22.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 90.7/101.7 MB 23.0 MB/s eta 0:00:01
#    ------------------------------------- -- 96.2/101.7 MB 23.0 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.7 MB 23.1 MB/s eta 0:00:01
#    --------------------------------------  101.4/101.7 MB 23.0 MB/s eta 0:00:01
#    --------------------------------------  101.4/101.7 MB 23.0 MB/s eta 0:00:01
#    --------------------------------------  101.4/101.7 MB 23.0 MB/s eta 0:00:01
#    --------------------------------------- 101.7/101.7 MB 19.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.2.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# Function for model fitting, model evaluation and Visualization.

# %%
def XGB_model(X,y):
    print("Spliting Datasets....")
    from sklearn.model_selection import train_test_split
    np.random.seed(42)
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
    print("Successfully splitted!!!")
    
    print("Model Fitting.....")
    xgb = XGBClassifier()
    xgb.fit(X_train, y_train)
    print("Successfully model fitted!!!")

    print("------------Training Prediction--------------")
    y_preds = xgb.predict(X_train)
    print(f"Classfifcation Report:\n\n{classification_report(y_train, y_preds)}\n\n")

    cf_matrix = confusion_matrix(y_train, y_preds)

    fig, ax = plt.subplots(figsize=(6,4))
    sns.heatmap(cf_matrix, annot=True, cmap='coolwarm', fmt='g')
    fig.suptitle(t="Confusion Matrix",
                 color="orange",
                 fontsize=16);
    ax.set(xlabel="Predicted Label",
           ylabel="Actual Label");

    print(f"Accuracy Score:\n\n{accuracy_score(y_train, y_preds)*100:2f}%\n")

    print("------------Test Prediction--------------")

    y_preds = xgb.predict(X_test)
    print(f"Classfifcation Report:\n\n{classification_report(y_test, y_preds)}\n\n")

    cf_matrix = confusion_matrix(y_test, y_preds)

    fig, ax = plt.subplots(figsize=(6,4))
    sns.heatmap(cf_matrix, annot=True, cmap='coolwarm', fmt='g')
    fig.suptitle(t="Confusion Matrix",
                 color="orange",
                 fontsize=16);
    ax.set(xlabel="Predicted Label",
           ylabel="Actual Label");

    print(f"Accuracy Score:\n\n{accuracy_score(y_test, y_preds)*100:2f}%\n")

# %% [markdown]
# XGBClassifier on Normal Datasets.

# %%
XGB_model(main.X, main.y)
# Out:
# Spliting Datasets....
# Successfully splitted!!!
# Model Fitting.....
# Successfully model fitted!!!
# ------------Training Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00       394
#
#     accuracy                           1.00    227845
#    macro avg       1.00      1.00      1.00    227845
# weighted avg       1.00      1.00      1.00    227845
#
#
#
# Accuracy Score:
#
# 100.000000%
#
# ------------Test Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.80      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.90      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
#
# Accuracy Score:
#
# 99.954356%

# %% [markdown]
# XGBClassifier on StandardScaled Dataset

# %%
XGB_model(main.X_scaled, main.y_scaled)
# Out:
# Spliting Datasets....
# Successfully splitted!!!
# Model Fitting.....
# Successfully model fitted!!!
# ------------Training Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00       394
#
#     accuracy                           1.00    227845
#    macro avg       1.00      1.00      1.00    227845
# weighted avg       1.00      1.00      1.00    227845
#
#
#
# Accuracy Score:
#
# 100.000000%
#
# ------------Test Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.80      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.90      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
#
# Accuracy Score:
#
# 99.954356%

# %% [markdown]
# XGBClassifier on Undersampled Dataset

# %%
XGB_model(main.X_undersampled, main.y_undersampled)
# Out:
# Spliting Datasets....
# Successfully splitted!!!
# Model Fitting.....
# Successfully model fitted!!!
# ------------Training Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       393
#            1       1.00      1.00      1.00       394
#
#     accuracy                           1.00       787
#    macro avg       1.00      1.00      1.00       787
# weighted avg       1.00      1.00      1.00       787
#
#
#
# Accuracy Score:
#
# 100.000000%
#
# ------------Test Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        99
#            1       0.95      0.89      0.92        98
#
#     accuracy                           0.92       197
#    macro avg       0.92      0.92      0.92       197
# weighted avg       0.92      0.92      0.92       197
#
#
#
# Accuracy Score:
#
# 91.878173%

# %% [markdown]
# XGBClassifier on Oversampled Dataset

# %%
XGB_model(main.X_oversampled, main.y_oversampled)
# Out:
# Spliting Datasets....
# Successfully splitted!!!
# Model Fitting.....
# Successfully model fitted!!!
# ------------Training Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227335
#            1       1.00      1.00      1.00    227569
#
#     accuracy                           1.00    454904
#    macro avg       1.00      1.00      1.00    454904
# weighted avg       1.00      1.00      1.00    454904
#
#
#
# Accuracy Score:
#
# 100.000000%
#
# ------------Test Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56980
#            1       1.00      1.00      1.00     56746
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
#
#
# Accuracy Score:
#
# 99.993845%

# %% [markdown]
# XGBClassifier on SMOTE Dataset

# %%
XGB_model(main.X_smote, main.y_smote)
# Out:
# Spliting Datasets....
# Successfully splitted!!!
# Model Fitting.....
# Successfully model fitted!!!
# ------------Training Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227565
#            1       1.00      1.00      1.00    227339
#
#     accuracy                           1.00    454904
#    macro avg       1.00      1.00      1.00    454904
# weighted avg       1.00      1.00      1.00    454904
#
#
#
# Accuracy Score:
#
# 99.999780%
#
# ------------Test Prediction--------------
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56750
#            1       1.00      1.00      1.00     56976
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
#
#
# Accuracy Score:
#
# 99.984172%

# %% [markdown]
# CONCLUSION:
# a) Undersampling doesn't work efficiently for Large majority class datasets as it ignores many valuable tuples. But, can be efficient for small majority class datasets
#
# b) It works even efficiently for this imbalanced datasets.
#
# c) It takes around 1 minute for training.
#
# d) Maximum Accuracy of 99.993845% and macro-average of F1-Score of 1.00 acheived with Oversampling technique.
